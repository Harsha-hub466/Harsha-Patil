# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha-hub466/Harsha-Patil/blob/main/CIE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/tips.csv')
print(df.head())
print(df.describe())
print(df.info())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   2.0
# 1       10.34  1.66    Male     No  Sun  Dinner   3.0
# 2       21.01  3.50    Male    NaN  Sun     NaN   3.0
# 3       23.68  3.31    Male     No  Sun  Dinner   2.0
# 4       24.59  3.61  Female     No  Sun  Dinner   4.0
#        total_bill         tip        size
# count  242.000000  244.000000  243.000000
# mean    19.827727    2.998279    2.572016
# std      8.910778    1.383638    0.952356
# min      3.070000    1.000000    1.000000
# 25%     13.375000    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.222500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  242 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         241 non-null    object
#  3   smoker      241 non-null    object
#  4   day         244 non-null    object
#  5   time        242 non-null    object
#  6   size        243 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 13.5+ KB
# None

# %%
df.isnull().sum()
# Out:
# total_bill    1
# tip           0
# sex           1
# smoker        0
# day           0
# time          1
# size          0
# dtype: int64

# %%
df=df.fillna(0)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male      0   Sun       0   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [244 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/tips.csv')
plt.scatter(df['total_bill'], df['tip'])
plt.title('scatter plot')
plt.show()

# %%
print(df['time'].describe())
# Out:
# count        242
# unique         2
# top       Dinner
# freq         174
# Name: time, dtype: object
